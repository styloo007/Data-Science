# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('CarPrice_Assignment.csv')
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
int_=data.dtypes=='int64'
int__=list(int_[int_].index)
print("List of INT Values: ")
print(int__)

float_=data.dtypes=='float64'
float__=list(float_[float_].index)
print("List of FLOAT Values: ")
print(float__)

cat_=data.dtypes=='object'
cat__=list(cat_[cat_].index)
print("List of Categorical Values: ")
print(cat__)
# Out:
# List of INT Values:
# ['car_ID', 'symboling', 'curbweight', 'enginesize', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']
# List of FLOAT Values:
# ['wheelbase', 'carlength', 'carwidth', 'carheight', 'boreratio', 'stroke', 'compressionratio', 'price']
# List of Categorical Values:
# ['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']

# %%
num_list=int__+float__
plt.figure(figsize=(6,6))
sns.heatmap(data[num_list].corr())
plt.show()

# %%
# List of Number of Unique Values

for i in int__:
    print("INT- ", i, "- ", data[i].nunique())

for j in float__:
    print("FLOAT- ", j, "- ", data[j].nunique())

for k in cat__:
    print("CAT- ", k, "- ", data[k].nunique())
# Out:
# INT-  car_ID -  205
# INT-  symboling -  6
# INT-  curbweight -  171
# INT-  enginesize -  44
# INT-  horsepower -  59
# INT-  peakrpm -  23
# INT-  citympg -  29
# INT-  highwaympg -  30
# FLOAT-  wheelbase -  53
# FLOAT-  carlength -  75
# FLOAT-  carwidth -  44
# FLOAT-  carheight -  49
# FLOAT-  boreratio -  38
# FLOAT-  stroke -  37
# FLOAT-  compressionratio -  32
# FLOAT-  price -  189
# CAT-  CarName -  147
# CAT-  fueltype -  2
# CAT-  aspiration -  2
# CAT-  doornumber -  2
# CAT-  carbody -  5
# CAT-  drivewheel -  3
# CAT-  enginelocation -  2
# CAT-  enginetype -  7
# CAT-  cylindernumber -  7
# CAT-  fuelsystem -  8

# %%
data.drop(columns='car_ID', inplace=True)

# %%
encoded_data=pd.get_dummies(data, columns=cat__, drop_first=True)

# %%
encoded_data.columns
# Out:
# Index(['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        ...
#        'cylindernumber_three', 'cylindernumber_twelve', 'cylindernumber_two',
#        'fuelsystem_2bbl', 'fuelsystem_4bbl', 'fuelsystem_idi',
#        'fuelsystem_mfi', 'fuelsystem_mpfi', 'fuelsystem_spdi',
#        'fuelsystem_spfi'],
#       dtype='object', length=190)

# %%
X=encoded_data.drop(columns='price')

Y= encoded_data['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

model=Lasso(alpha=1.0, max_iter=3433)


model.fit(X_train, Y_train)
# Out:
# Lasso(max_iter=3433)

# %%
predictions=model.predict(X_test)

# %%
predictions
# Out:
# array([20817.42845239, 21637.04562911, 10511.7915444 , 13259.18007296,
#        28138.13327306,  5860.89575534,  7762.08797303,  8414.38551833,
#         9822.08469571,  8305.66882616, 17105.75228109,  6168.7844994 ,
#        17866.52454739,  9053.92313578, 38701.34659301,  6776.56120897,
#        -2229.20250151, 13099.86314131, 11408.81381794, 10789.70913398,
#        11136.17991025, 18417.91436939,  7575.88378716,  3217.76584438,
#         8546.17192752, 21913.95576496, 12341.13027492, 14494.26876086,
#         4552.36714148, 15139.41930176, 27517.87826535,  6693.0020951 ,
#         6388.12094369, 17921.9436817 ,  7077.21954024, 27546.55350445,
#        12826.63021696,  8899.28013397,  7807.72907409, 15740.89437435,
#         7504.20304822])

# %%
Y_test=(Y_test>=0.5).astype(int)

predictions_binary= (predictions>=0.5).astype(int)

# %%
print("Classification Report: ", classification_report(Y_test, predictions_binary))
# Out:
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.98      0.99        41
#
#     accuracy                           0.98        41
#    macro avg       0.50      0.49      0.49        41
# weighted avg       1.00      0.98      0.99        41
# c:\Users\shash\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\shash\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print("Accuracy Score: ", accuracy_score(Y_test, predictions_binary))
# Out:
# Accuracy Score:  0.975609756097561

# %%
print("Confusion Matrix: \n", confusion_matrix(Y_test, predictions_binary))
# Out:
# Confusion Matrix:
#  [[ 0  0]
#  [ 1 40]]
